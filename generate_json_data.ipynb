# %% [markdown]
# # Dataset creation
# Document understanding dataset creation base on FUNSD.

# %% [markdown]
# ## 1. Setup google drive
# ---

# %%
# %%capture
# PDF data packages 
# !pip install pdfminer
# !pip install PyMuPDF

# connect to drive
from google.colab import drive
drive.mount('/content/drive')

# global variables
base_path = "/content/drive/MyDrive"
pdf_dataset_path = "/content/drive/MyDrive/form_dataset"
png_dataset_path = "/content/drive/MyDrive/COMP5703_dataset"
dataset_off_set = 7130

# %% [markdown]
# ## 2. Create PNG
# ---

# %%
# pip packages 
from pathlib import Path
import glob, sys, fitz
import pandas as pd
import numpy as np
import ntpath
import tqdm
import os

# Create folder at google drive 
def create_folder(base_path, folder_name):
  folder_path = base_path + '/' + folder_name
  Path(folder_path).mkdir(parents = True, exist_ok = True)
  return folder_path

# read files under path
def read_files(path, off_set = False):
  if (off_set == False):
    all_files = os.listdir(path)
  else:
    all_files = os.listdir(path)[:off_set]

  return all_files

# %%
# pip packages 
from pathlib import Path
import glob, sys, fitz
import pandas as pd
import numpy as np
import ntpath
import tqdm
import os


# Create folder at google drive 
def create_folder(base_path, folder_name):
  folder_path = base_path + '/' + folder_name

  try:
    Path(folder_path).mkdir(parents = True, exist_ok = True)
    return folder_path
  except:
    print("create_folder(): Fail {} at {}".format(base_path, folder_name))
  
  return False


# read files under path
def read_files(path, off_set = False):
  if (off_set == False):
    all_files = os.listdir(path)
  else:
    all_files = os.listdir(path)[:off_set]

  return all_files


def create_dataset(off_set = False):
  print("create_dataset(): Start")

  png_path = create_folder(base_path, "COMP5703_dataset")
  print("    Success create PNG folder at {}".format(png_path))

  all_files = read_files(pdf_dataset_path, off_set = off_set)
  print("    Success read {} pdf files at {}".format(len(all_files), pdf_dataset_path))
  
  pdf_counter = 0
  png_counter = 0
  failure_pdf = []
  failure_png = []

  for pdf_file in all_files:
    # open pdf file 
    try:
      pdf_code = pdf_file.split('.')[0]
      pdf_path = pdf_dataset_path + '/' + pdf_file
      document = fitz.open(pdf_path)

    except:
      failure_pdf = failure_pdf.append(pdf_path)
      pass

    # iterate through all pages
    for page in document:
      try: 
        pix = page.get_pixmap()

        # save png file
        png_path = "{}-{}.png".format(png_dataset_path + '/' + pdf_code, page.number)
        pix.save(png_path)
        png_counter = png_counter + 1
      except:
        failure_png = failure_png.append(png_path)
        pass
    
    pdf_counter = pdf_counter + 1
  
  print("    create_dataset(): {}/{} pdf files readed".format(pdf_counter, len(all_files)))
  print("    create_dataset(): {} png files saved".format(png_counter))

  return failure_png, failure_pdf

def save_json(dict_data):
  try:
    json_file = open('data.json', "w")
    json.dump(dict_data, json_file)
  except:
    print("    save_json(): fail save as JSON")
  finally:
    return dict_data

# ---------- local cell main ----------
#failure_png, failure_pdf = create_dataset(off_set = dataset_off_set)

#if (len(failure_pdf) > 0 or len(failure_png) > 0):
#  print(failure_pdf)
#  print(failure_png)

# %% [markdown]
# ## 3. Bounding box extraction
# ---

# %%
# PDF data packages 
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.layout import LAParams, LTTextBox, LTTextLine, LTFigure
from pdfminer.converter import PDFPageAggregator
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfpage import PDFPage

# CV
import cv2
from google.colab.patches import cv2_imshow

# pip packages 
from pathlib import Path
import glob, sys, fitz
import pandas as pd
import numpy as np
import ntpath
import tqdm
import json
import math
import os


def merge_box(box1, box2):
  return [min(box1[0], box2[0]), max(box1[1], box2[1]), max(box1[2], box2[2]), min(box1[3], box2[3])]

def get_box_distance(box1, box2):
  return min(box2[3] - box1[1], box1[3] - box2[1], box1[1] - box2[3], box2[1] - box1[3])


def merge_algo(sub_boxes, threshold):
  result = sub_boxes
  for i in range(len(sub_boxes)):
    for j in range(len(sub_boxes)):
      if (j <= i):
        continue
      if (get_box_distance(sub_boxes[i], sub_boxes[j]) <= verti_threshold):
        new_box = merge_box(sub_boxes[i], sub_boxes[j])            
        result[i] = new_box
        result.pop(j)
        return True, result

  return False, result


def merge_boxes(box_list, threshold):
  clean_box = []
  for box in box_list:
    width, height = get_box_detail(box)
    if (width > 5 and height > 5):
      clean_box.append(box)
    else:
      continue
  
  need_to_merge = True
  tmp_box = clean_box
  while need_to_merge:
    need_to_merge, tmp_box = merge_algo(tmp_box, threshold)

  sub_obj = {}
  for index in range(len(tmp_box)):
    sub_obj[index] = {}
    sub_obj[index]['coord'] = tmp_box[index]

  return sub_obj


def get_box_detail(coord):
  x1 = coord[0]
  y1 = coord[1]
  x2 = coord[2]
  y2 = coord[3]
  return abs(x2 - x1), abs(y2 - y1)


def get_box(sizeRatioW, sizeRatioH, pageW, pageH, bbox):
  x1 = int(bbox[0] * sizeRatioW)
  y1 = int(pageH - bbox[1] * sizeRatioH)
  x2 = int(bbox[2] * sizeRatioW)
  y2 = int(pageH - bbox[3] * sizeRatioH)
  return [x1, y1, x2, y2]

def get_png_data(layout, sizeRatioW, sizeRatioH, pageW, pageH, merge = False):
  png_dict = {}
  upper_index = 0

  for lt_obj in layout:
    if isinstance(lt_obj, LTTextBox) or isinstance(lt_obj, LTTextLine):
      upper_box = get_box(sizeRatioW, sizeRatioH, pageW, pageH, lt_obj.bbox)
      box_width, box_height = get_box_detail(upper_box)
      if (box_width <= 5 or box_height <= 5):
        continue
      else:
        png_dict[upper_index] = {}
        png_dict[upper_index]['lt_obj'] = upper_box
        # don't merge sub boxs 
        sub_index = 0
        sub_dict = {}
        merge_list = []
        for obj in lt_obj:
          sub_box = get_box(sizeRatioW, sizeRatioH, pageW, pageH, obj.bbox)
          box_width, box_height = get_box_detail(sub_box)
          if (merge == False):
            if (box_width <= 5 or box_height <= 5):
              continue
            else:
              sub_dict[sub_index] = {}
              sub_dict[sub_index]['coord'] = sub_box
              sub_index = sub_index + 1
          else:
            merge_list.append(sub_box)

      if(merge == True):
          sub_dict = merge_boxes(merge_list, global_dist_threshold)
        
      png_dict[upper_index]['sub_obj'] = sub_dict
      upper_index = upper_index + 1
  
      
  return png_dict


def get_pdf_data(pdf_name, merge = False):
  # set config and path 
  pdf_code = pdf_name.split('.')[0]
  pdf_path = pdf_dataset_path + '/' + pdf_name
  pdf_file = open(pdf_path, 'rb')

  # process pdf
  parser = PDFParser(pdf_file)
  document = PDFDocument(parser)
  rsrcmgr = PDFResourceManager()
  laparams = LAParams()
  device = PDFPageAggregator(rsrcmgr, laparams = laparams)
  interpreter = PDFPageInterpreter(rsrcmgr, device)

  # pdf level dict
  pdf_dict = {}
  pdf_dict['document_id'] = pdf_code
  pdf_dict['pages'] = {}

  # iterate all pages 
  page_index = 0
  for page in PDFPage.create_pages(document):
    # set config for image 
    png_name = "{}-{}.png".format(pdf_code, page_index)
    png_path = "{}/{}-{}.png".format(png_dataset_path, pdf_code, page_index)
    pdf_dict['pages'][page_index] = {}
    pdf_dict['pages'][page_index]['page_name'] = png_name

    # read image
    png = cv2.imread(png_path, cv2.IMREAD_UNCHANGED)
    height, width, channels = png.shape
    pageW = page.mediabox[2]
    pageH = page.mediabox[3] 
    sizeRatioW =  width / page.mediabox[2]
    sizeRatioH =  height / page.mediabox[3]
    pdf_dict['pages'][page_index]['height'] = pageH
    pdf_dict['pages'][page_index]['width'] = pageW
    pdf_dict['pages'][page_index]['objects'] = {}

    # get layout
    interpreter.process_page(page)
    layout = device.get_result()
    pdf_dict['pages'][page_index]['objects'] = get_png_data(layout, sizeRatioW, sizeRatioH, pageW, pageH, merge = merge)

    page_index = page_index + 1


  return pdf_dict

# iterate all 
def build_json(off_set = False, show = False, merge = False):
  all_pdf = read_files(pdf_dataset_path, off_set = off_set)
  fail_pdf_list = []
  pdf_level_dict = {}
  process = 0
  print("current: {}".format(process))
  for pdf in all_pdf:
    try:
      pdf_level_dict[pdf] = get_pdf_data(pdf, merge = merge)
    except:
      fail_pdf_list.append(pdf)
    
    if process % 200 == 0 and process >= 200:
      print("{}/{} completed".format(process, len(all_pdf)))
      save_json(pdf_level_dict)

    process = process + 1

  return pdf_level_dict, fail_pdf_list

global_dist_threshold = 5
verti_threshold = 5 
json_data, fail_pdf_list = build_json(off_set = dataset_off_set, show = False, merge = True)
save_json(json_data)
# Out:
# current: 0
# 200/7130 completed

# %%
print(json_data)
print(fail_pdf_list)
# Out:
# {}
# ['01938902.pdf', '01938906.pdf', '01938979.pdf', '01939104.pdf', '01939177.pdf', '01939210.pdf', '01939212.pdf', '01939244.pdf', '01939260.pdf', '01939347.pdf', '01939411.pdf', '01939443.pdf', '01939460.pdf', '01939560.pdf', '01939568.pdf', '01939632.pdf', '01939635.pdf', '01939638.pdf', '01939652.pdf', '01939653.pdf', '01939655.pdf', '01939715.pdf', '01939724.pdf', '01939836.pdf', '01939894.pdf', '01939897.pdf', '01939925.pdf', '01940013.pdf', '01940025.pdf', '01940026.pdf', '01940141.pdf', '01940195.pdf', '01940205.pdf', '01940271.pdf', '01940315.pdf', '01940380.pdf', '01940433.pdf', '01940453.pdf', '01940663.pdf', '01940686.pdf', '01940701.pdf', '01940716.pdf', '01940761.pdf', '01940815.pdf', '01940823.pdf', '01940859.pdf', '01940868.pdf', '01940877.pdf', '01940926.pdf', '01940966.pdf', '01941035.pdf', '01941038.pdf', '01941039.pdf', '01941043.pdf', '01941237.pdf', '01941291.pdf', '01941348.pdf', '01941602.pdf', '01941735.pdf', '01941743.pdf', '01941753.pdf', '01941775.pdf', '01941825.pdf', '01941840.pdf', '01941855.pdf', '01942011.pdf', '01942053.pdf', '01942066.pdf', '01942230.pdf', '01942247.pdf', '01942279.pdf', '01942286.pdf', '01942295.pdf', '01942330.pdf', '01942385.pdf', '01942435.pdf', '01942454.pdf', '01942607.pdf', '01942671.pdf', '01942772.pdf', '01942961.pdf', '01943117.pdf', '01943308.pdf', '01943428.pdf', '01943496.pdf', '01943555.pdf', '01943569.pdf', '01943579.pdf', '01943665.pdf', '01943677.pdf', '01943779.pdf', '01943813.pdf', '01943867.pdf', '01943960.pdf', '01943981.pdf', '01944009.pdf', '01944044.pdf', '01944144.pdf', '01944245.pdf', '01944550.pdf', '01944552.pdf', '01944593.pdf', '01944613.pdf', '01944635.pdf', '01944674.pdf', '01944887.pdf', '01944889.pdf', '01945032.pdf', '01945071.pdf', '01945184.pdf', '01945238.pdf', '01945248.pdf', '01945422.pdf', '01945469.pdf', '01945576.pdf', '01945665.pdf', '01946154.pdf', '01946381.pdf', '01946561.pdf', '01946617.pdf', '01946823.pdf', '01946872.pdf', '01946884.pdf', '01946890.pdf', '01946893.pdf', '01946895.pdf', '01946906.pdf', '01946956.pdf', '01946981.pdf', '01947000.pdf', '01947005.pdf', '01947013.pdf', '01947167.pdf', '01947174.pdf', '01947300.pdf', '01947308.pdf', '01947388.pdf', '01947559.pdf', '01947570.pdf', '01947617.pdf', '01947620.pdf', '01947691.pdf', '01947702.pdf', '01947703.pdf', '01947727.pdf', '01947759.pdf', '01947763.pdf', '01947837.pdf', '01947839.pdf', '01948095.pdf', '01948102.pdf', '01948108.pdf', '01948124.pdf', '01948145.pdf', '01948228.pdf', '01948229.pdf', '01948341.pdf', '01948343.pdf', '01948472.pdf', '01948555.pdf', '01948724.pdf', '01948816.pdf', '01948892.pdf', '01948945.pdf', '01948950.pdf', '01948952.pdf', '01948953.pdf', '01948975.pdf', '01948976.pdf', '01948982.pdf', '01949148.pdf', '01949167.pdf', '01949175.pdf', '01949193.pdf', '01949240.pdf', '01949241.pdf', '01949426.pdf', '01949427.pdf', '01949529.pdf', '01949591.pdf', '01949652.pdf', '01949706.pdf', '01949770.pdf', '01949791.pdf', '01949802.pdf', '01949806.pdf', '01950057.pdf', '01950069.pdf', '01950131.pdf', '01950164.pdf', '01950165.pdf', '01950168.pdf', '01950173.pdf', '01950296.pdf', '01950298.pdf', '01950466.pdf', '01950490.pdf', '01950536.pdf', '01950578.pdf', '01950579.pdf', '01950669.pdf', '01950718.pdf', '01950729.pdf', '01950893.pdf', '01951054.pdf', '01951135.pdf', '01951143.pdf', '01951145.pdf', '01951210.pdf', '01951220.pdf', '01951412.pdf', '01951485.pdf', '01951530.pdf', '01951532.pdf', '01951533.pdf', '01951953.pdf', '01951955.pdf', '01952029.pdf', '01952043.pdf', '01952081.pdf', '01952089.pdf', '01952104.pdf', '01952119.pdf', '01952120.pdf', '01952140.pdf', '01952593.pdf', '01952738.pdf', '01952876.pdf', '01953696.pdf', '01953973.pdf', '01954214.pdf', '01954513.pdf', '01954520.pdf', '01954634.pdf', '01954637.pdf', '01954647.pdf', '01954650.pdf', '01954690.pdf', '01954691.pdf', '01955116.pdf', '01955183.pdf', '01955289.pdf', '01955339.pdf', '01955586.pdf', '01955760.pdf', '01955911.pdf', '01955972.pdf', '01955977.pdf', '01955992.pdf', '01955999.pdf', ...

# %%
def save_json(dict_data):
  try:
    json_file = open('data.json', "w")
    json.dump(dict_data, json_file)
  except:
    print("    save_json(): fail save as JSON")
  finally:
    return dict_data

# %% [markdown]
# ### 3.3 Visualisation
# ---

# %%
import cv2


# draw all boxes on image 
def draw_box(json_data, off_set = False, show_upper = True):
  for pdf in json_data:
    pages = json_data[pdf]['pages']
    
    for page in pages:
      objects = pages[page]['objects']
      png_name = pages[page]['page_name']
      png_image = cv2.imread(png_dataset_path + '/' + png_name, cv2.IMREAD_UNCHANGED)

      for upper_index in objects:
        upper_box = objects[upper_index]['lt_obj']
        sub_box_list = objects[upper_index]['sub_obj']

        for sub_index in sub_box_list:
          sub_box = sub_box_list[sub_index]['coord']
          cv2.rectangle(png_image, (sub_box[0], sub_box[1]), (sub_box[2], sub_box[3]), (0, 255, 0, 255), 1)

        if (show_upper == True):
          cv2.rectangle(png_image, (upper_box[0], upper_box[1]), (upper_box[2], upper_box[3]), (0, 0, 255, 255), 1)
      
    cv2_imshow(png_image)

  return False


draw_box(json_data, off_set = False, show_upper = False)
# Out:
# False

# %% [markdown]
# ## OCR

# %% [markdown]
# We provide sample codes for OCR by using Google Cloud Vision. You need to create a Google Cloud Vision account with JSON keys. (Each Group Member at least create one account since our dataset is very large.)

# %%
# !pip3 install --upgrade google-cloud-vision
# Out:
# Collecting google-cloud-vision
#   Downloading google_cloud_vision-2.7.2-py2.py3-none-any.whl (383 kB)
#      |████████████████████████████████| 383 kB 6.6 MB/s
# Collecting google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5
#   Downloading google_api_core-2.7.1-py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 19.4 MB/s
# Collecting proto-plus>=1.15.0
#   Downloading proto_plus-1.20.3-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 1.9 MB/s
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (3.17.3)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (1.56.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (2.23.0)
# Collecting grpcio-status<2.0dev,>=1.33.2
#   Downloading grpcio_status-1.45.0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (1.44.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (1.15.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (57.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (0.2.8)
# Collecting grpcio<2.0dev,>=1.33.2
#   Downloading grpcio-1.45.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 37.1 MB/s
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.19.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 47.6 MB/s
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-vision) (3.0.4)
# WARNING: The candidate selected for download or install is a yanked version: 'grpcio' candidate (version 1.45.0 at https://files.pythonhosted.org/packages/b8/ab/c7abc950e222c4cab5f7fd92107f3b09553061f673f1a670e6569105f584/grpcio-1.45.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=cc135b77f384a84bac67a37947886986be136356446338d64160a30c85f20c6d (from https://pypi.org/simple/grpcio/) (requires-python:>=3.6))
# Reason for being yanked: Segfaults
# Installing collected packages: protobuf, grpcio, grpcio-status, google-api-core, proto-plus, google-cloud-vision
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.44.0
#     Uninstalling grpcio-1.44.0:
#       Successfully uninstalled grpcio-1.44.0
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 1.26.3
#     Uninstalling google-api-core-1.26.3:
#       Successfully uninstalled google-api-core-1.26.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# google-cloud-translate 1.5.0 requires google-api-core[grpc]<2.0.0dev,>=1.6.0, but you have google-api-core 2.7.1 which is incompatible.
# google-cloud-language 1.2.0 requires google-api-core[grpc]<2.0.0dev,>=1.6.0, but you have google-api-core 2.7.1 which is incompatible.
# google-cloud-firestore 1.7.0 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.7.1 which is incompatible.
# google-cloud-datastore 1.8.0 requires google-api-core[grpc]<2.0.0dev,>=1.6.0, but you have google-api-core 2.7.1 which is incompatible.
# google-cloud-core 1.0.3 requires google-api-core<2.0.0dev,>=1.14.0, but you have google-api-core 2.7.1 which is incompatible.
# google-cloud-bigquery-storage 1.1.0 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.7.1 which is incompatible.
# firebase-admin 4.4.0 requires google-api-core[grpc]<2.0.0dev,>=1.14.0; platform_python_implementation != "PyPy", but you have google-api-core 2.7.1 which is incompatible.
# Successfully installed google-api-core-2.7.1 google-cloud-vision-2.7.2 grpcio-1.45.0 grpcio-status-1.45.0 proto-plus-1.20.3 protobuf-3.19.4

# %%
import os 
print(os.getcwd())
# Out:
# /content

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] ="/content/i-mariner-344411-a88c2da9e583.json"

# %%
from google.cloud import vision
client = vision.ImageAnnotatorClient()

# %% [markdown]
# ### OCR for Bounding Box

# %% [markdown]
# #### Cropping Bounding Box images

# %%
import cv2
import os
for img in list(image_dict['/content/form_dataset/00346615'].keys()):
  dir = '/content/'+ img # Change to your image storage directory
  image = cv2.imread(dir)
  img_name = img.split('/')[-1]
  img_name = img_name.split('.')[0]

  for obj in image_dict['00346615'][img]['objects']:
    objt = image_dict['00346615'][img]['objects'][obj]
    #print(objt['bbox'])
    x = objt['bbox'][0]
    y = objt['bbox'][1]
    w = objt['bbox'][2]
    h = objt['bbox'][3]
    
    crop_img = image[h:y, x:w]
    cv2_imshow(crop_img)
    cv2.waitKey(0)
    
    # Change to your Google drive path for storing those cropped images based on the extracted bounding box coordinates
    try:
      os.mkdir('/content/drive/MyDrive/form_understanding_dataset/ocr_testing/'+img_name)
    except:
      pass
    save_dir = '/content/drive/MyDrive/form_understanding_dataset/ocr_testing'+'/'+img_name+'/'+str(obj)+'.jpg'
    cv2.imwrite(save_dir,crop_img)

# %% [markdown]
# #### OCR for Croped Images

# %%
for pdf in image_dict:
  for image_name in image_dict[pdf]:
    for i in range(len(image_dict[pdf][image_name]['objects'])):
      # Change this to your cropped image path
      dir = '/content/drive/MyDrive/form_understanding_dataset/ocr_testing/00346615-0/'+str(i)+'.jpg'
      with io.open(dir, 'rb') as image_file:
        content = image_file.read()
      image = vision.Image(content=content)
      try:
        response = client.text_detection(image = image)
        texts = response.text_annotations
        image_dict[pdf][image_name]['objects'][str(i)]['text'] = texts[0].description
        # please change code from here to add the token level information based on extracted text from google cloud vision API
      except:
        pass
      if response.error.message:
        raise Exception('{}\nFor more info on error messages, check: ''https://cloud.google.com/apis/design/errors'.format(response.error.message))

# %%
import json
with open('/content/drive/MyDrive/form_understanding_dataset/test_dataset_info.json','w') as f:
  json.dump(image_dict,f)

# %% [markdown]
# ### OCR for Scanned Documents

# %% [markdown]
# #### Get Scanned Documents

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import pandas as pd

# Authenticate
drive = None
def authenticate():
  global drive
  
  auth.authenticate_user()
  gauth = GoogleAuth()
  gauth.credentials = GoogleCredentials.get_application_default()
  drive = GoogleDrive(gauth)

#Download files
def downloadFiles(fileIds):
  authenticate()
  
  for fileId in fileIds:    
    
    downloaded = drive.CreateFile({"id": fileId[1]})
    downloaded.GetContentFile(fileId[0])

# %%
try:
  _ = open("604_5000.zip", "r")
except:
  downloadFiles([["604_5000.zip", "1XEQB9hhVDjKDO5_OdbEjsKJTeqeEna7U"]])

# %%
# !mkdir /content/form_dataset
!7za e /content/604_5000.zip -o/content/form_dataset
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 845025911 bytes (806 MiB)
#
# Extracting archive: /content/604_5000.zip
# --
# Path = /content/604_5000.zip
# Type = zip
# Physical Size = 845025911
#
# Everything is Ok
#
# Files: 5000
# Size:       873349732
# Compressed: 845025911

# %% [markdown]
# ### Convert PDF to Images
# Please use the Create Image Functions

# %%
# !pip install fitz
# !pip install PyMuPDF
import glob, sys, fitz
import os
from pathlib import Path
def createImages(foldername):
    num = 1
    
    all_files = os.listdir(foldername)[:100]
    Path("./images").mkdir(parents=True, exist_ok=True)
    print(all_files)
    num_10 = 0
    num_5  = 0
    for filename in all_files:
        print(num)
        num+=1
        path = foldername + '/' + filename
        doc = fitz.open(path)  # open document
        i = 0
        for page in doc:  # iterate through the pages
            i += 1
            pix = page.get_pixmap()  # render page to an image
            filename = filename.split('.')[0]
            filename = filename.split('/')[-1]
            # Change the direction to your own google drive
            filename = '/content/images/'+filename
            pix.save("{}_page-{}.png".format(filename, page.number))  # store image as a PNG

foldername = "/content/form_dataset"
createImages(foldername)

# %% [markdown]
# ### OCR

# %%
import io
from google.cloud import vision
for i in range(0,1):
  # Change this to your splitted document image path
  dir = '/content/images/00344564_page-' + str(i) + '.png'
  with io.open(dir, 'rb') as image_file:
    content = image_file.read()
  image = vision.Image(content=content)
  #try:
  
  response = client.text_detection(image = image)
  
  texts = response.text_annotations
  # Please Store the extracted Texts into json file based on the provided json format
  print(texts)  
  #except:
    #print("pass")
    #pass
  if response.error.message:
    raise Exception('{}\nFor more info on error messages, check: ''https://cloud.google.com/apis/design/errors'.format(response.error.message))
# Out:
# [locale: "en"
# description: "13. Feb. 2013 10:50\nSSB AUSTRALIA 612 92512997\nNc. 5167 P. 1/7\nSALOMON SMITHBARNEY\nAmemberof citigroup.\nfacsimile\nTo:\nThe IndexShares Fund\nFax:\n61 2 8295 8659\nTo:\nAustralian Stock Exchange Limited\nFax:\n1300 300 021\nFrom:\nVictoria Weekes\nFax:\n61 2 8225 5461\nCompany Secretary\nDate:\n13 February 2003\nPages:\n7 (Including cover sheet)\nSubject:\nSubstantial Shareholding Notice\nIf you do not receive all pages, please telephone on 61 2 82254965.\nThis fax is confidential and may be privileged. If you are not the intended recipient, please notify the sender immediately by telephone.\nSee attached.\nDocument2\nSALOMON SMITH BARNEY AUSTRALIA PTY LIMITED\nABN 56 081 472684\nLevel 40, Citigroup Centre, 2 Park Street, Sydney NSW 2000\nGPO Box 557, Sydney NSW 2001 Australia\nTELEPHONE: 61282254000\nFACSIMILE:\n61 2 8225 5461\n"
# bounding_poly {
#   vertices {
#     x: 130
#   }
#   vertices {
#     x: 1558
#   }
#   vertices {
#     x: 1558
#     y: 2208
#   }
#   vertices {
#     x: 130
#     y: 2208
#   }
# }
# , description: "13."
# bounding_poly {
#   vertices {
#     x: 142
#     y: 8
#   }
#   vertices {
#     x: 169
#     y: 8
#   }
#   vertices {
#     x: 169
#     y: 35
#   }
#   vertices {
#     x: 142
#     y: 35
#   }
# }
# , description: "Feb."
# bounding_poly {
#   vertices {
#     x: 184
#     y: 8
#   }
#   vertices {
#     x: 231
#     y: 8
#   }
#   vertices {
#     x: 231
#     y: 35
#   }
#   vertices {
#     x: 184
#     y: 35
#   }
# }
# , description: "2013"
# bounding_poly {
#   vertices {
#     x: 246
#     y: 8
#   }
#   vertices {
#     x: 301
#     y: 8
#   }
#   vertices {
#     x: 301
#     y: 35
#   }
#   vertices {
#     x: 246
#     y: 35
#   }
# }
# , description: "10:50"
# bounding_poly {
#   vertices {
#     x: 340
#     y: 8
#   }
#   vertices {
#     x: 407
#     y: 8
#   }
#   vertices {
#     x: 407
#     y: 35
#   }
#   vertices {
#     x: 340
#     y: 35
#   }
# }
# , description: "SSB"
# bounding_poly {
#   vertices {
#     x: 506
#     y: 8
#   }
#   vertices {
#     x: 545
#     y: 8
#   }
#   vertices {
#     x: 545
#     y: 33
#   }
#   vertices {
#     x: 506
#     y: 33
#   }
# }
# , description: "AUSTRALIA"
# bounding_poly {
#   vertices {
#     x: 566
#     y: 8
#   }
#   vertices {
#     x: 699
#     y: 8
#   }
#   vertices {
#     x: 699
#     y: 33
#   }
#   vertices {
#     x: 566
#     y: 33
#   }
# }
# , description: "612"
# bounding_poly {
#   vertices {
#     x: 720
#     y: 8
#   }
#   vertices {
#     x: 758
#     y: 8
#   }
#   vertices {
#     x: 758
#     y: 35
#   }
#   vertices {
#     x: 720
#     y: 35
#   }
# }
# , description: "92512997"
# bounding_poly {
#   vertices {
#     x: 781
#     y: 8
#   }
#   vertices {
#     x: 895
#     y: 8
#   }
#   vertices {
#     x: 895
#     y: 35
#   }
#   vertices {
#     x: 781
#     y: 35
#   }
# }
# , description: "Nc."
# bounding_poly {
#   vertices {
#     x: 1216
#   }
#   vertices {
#     x: 1267
#   }
#   vertices {
#     x: 1267
#     y: 39
#   }
#   vertices {
#     x: 1216
#     y: 39
#   }
# }
# , description: "5167"
# bounding_poly {
#   vertices {
#     x: 1268
#     y: 8
#   }
#   vertices {
#     x: 1323
#     y: 8
#   }
#   vertices {
#     x: 1323
#     y: 35
#   }
#   vertices {
#     x: 1268
#     y: 35
#   }
# }
# , description: "P."
# bounding_poly {
#   vertices {
#     x: 1374
#     y: 8
#   }
#   vertices {
#     x: 1391
#     y: 8
#   }
#   vertices {
#     x: 1391
#     y: 35
#   }
#   vertices {
#     x: 1374
#     y: 35
#   }
# }
# , description: "1/7"
# bounding_poly {
#   vertices {
#     x: 1424
#     y: 6
#   }
#   vertices {
#     x: 1461
#     y: 6
#   }
#   vertices {
#     x: 1461
#     y: 35
#   }
#   vertices {
#     x: 1424
#     y: 35
#   }
# }
# , description: "SALOMON"
# bounding_poly {
#   vertices {
#     x: 246
#     y: 94
#   }
#   vertices {
#     x: 527
#     y: 94
#   }
#   vertices {
#     x: 527
#     y: 173
#   }
#   vertices {
#     x: 246
#     y: 173
#   }
# }
# , description: "SMITHBARNEY"
# bounding_poly {
#   vertices {
#     x: 530
#     y: 94
#   }
#   vertices {
#     x: 939
#     y: 94
#   }
#   vertices {
#     x: 939
#     y: 173
#   }
#   vertices {
#     x: 530
#     y: 173
#   }
# }
# , description: "Amemberof"
# bounding_poly {
#   vertices {
#     x: 620
#     y: 197
#   }
#   vertices {
#     x: 788
#     y: 200
#   }
#   vertices {
#     x: 788
#     y: 229
#   }
#   vertices {
#     x: 620
#     y: 226
#   }
# }
# , description: "citigroup."
# bounding_poly {
#   vertices {
#     x: 795
#     y: 195
#   }
#   vertices {
#     x: 942
#     y: 197
#   }
#   vertices {
#     x: 941
#     y: 234
#   }
#   vertices {
#     x: 794
#     y: 232
#   }
# }
# , description: "facsimile"
# bounding_poly {
#   vertices {
#     x: 232
#     y: 304
#   }
#   vertices {
#     x: 579
#     y: 304
#   }
#   vertices {
#     x: 579
#     y: 371
#   }
#   vertices {
#     x: 232
#     y: 371
#   }
# }
# , description: "To:"
# bounding_poly {
#   vertices {
#     x: 231
#     y: 450
#   }
#   vertices {
#     x: 273
#     y: 450
#   }
#   vertices {
#     x: 273
#     y: 471
#   }
#   vertices {
#     x: 231
#     y: 471
#   }
# }
# , description: "The"
# bounding_poly {
#   vertices {
#     x: 413
#     y: 450
#   }
#   vertices {
#     x: 462
#     y: 450
#   }
#   vertices {
#     x: 462
#     y: 471
#   }
#   vertices {
#     x: 413
#     y: 471
#   }
# }
# , description: "IndexShares"
# bounding_poly {
#   vertices {
#     x: 474
#     y: 450
#   }
#   vertices {
#     x: 633
#     y: 450
#   }
#   vertices {
#     x: 633
#     y: 471
#   }
#   vertices {
#     x: 474
#     y: 471
#   }
# }
# , description: "Fund"
# bounding_poly {
#   vertices {
#     x: 646
#     y: 450
#   }
#   vertices {
#     x: 708
#     y: 450
#   }
#   vertices {
#     x: 708
#     y: 471
#   }
#   vertices {
#     x: 646
#     y: 471
#   }
# }
# , description: "Fax:"
# bounding_poly {
#   vertices {
#     x: 942
#     y: 450
#   }
#   vertices {
#     x: 998
#     y: 451
#   }
#   vertices {
#     x: 998
#     y: 473
#   }
#   vertices {
#     x: 942
#     y: 472
#   }
# }
# , description: "61"
# bounding_poly {
#   vertices {
#     x: 1083
#     y: 449
#   }
#   vertices {
#     x: 1118
#     y: 449
#   }
#   vertices {
#     x: 1118
#     y: 479
#   }
#   vertices {
#     x: 1083
#     y: 479
#   }
# }
# , description: "2"
# bounding_poly {
#   vertices {
#     x: 1125
#     y: 452
#   }
#   vertices {
#     x: 1139
#     y: 452
#   }
#   vertices {
#     x: 1139
#     y: 473
#   }
#   vertices {
#     x: 1125
#     y: 473
#   }
# }
# , description: "8295"
# bounding_poly {
#   vertices {
#     x: 1151
#     y: 452
#   }
#   vertices {
#     x: 1213
#     y: 452
#   }
#   vertices {
#     x: 1213
#     y: 473
#   }
#   vertices {
#     x: 1151
#     y: 473
#   }
# }
# , description: "8659"
# bounding_poly {
#   vertices {
#     x: 1225
#     y: 452
#   }
#   vertices {
#     x: 1286
#     y: 452
#   }
#   vertices {
#     x: 1286
#     y: 473
#   }
#   vertices {
#     x: 1225
#     y: 473
#   }
# }
# , description: "To:"
# bounding_poly {
#   vertices {
#     x: 231
#     y: 518
#   }
#   vertices {
#     x: 272
#     y: 518
#   }
#   vertices {
#     x: 272
#     y: 539
#   }
#   vertices {
#     x: 231
#     y: 539
#   }
# }
# , description: "Australian"
# bounding_poly {
#   vertices {
#     x: 413
#     y: 518
#   }
#   vertices {
#     x: 541
#     y: 518
#   }
#   vertices {
#     x: 541
#     y: 539
#   }
#   vertices {
#     x: 413
#     y: 539
#   }
# }
# , description: "Stock"
# bounding_poly {
#   vertices {
#     x: 553
#     y: 518
#   }
#   vertices {
#     x: 623
#     y: 518
#   }
#   vertices {
#     x: 623
#     y: 539
#   }
#   vertices {
#     x: 553
#     y: 539
#   }
# }
# , description: "Exchange"
# bounding_poly {
#   vertices {
#     x: 634
#     y: 518
#   }
#   vertices {
#     x: 760
#     y: 518
#   }
#   vertices {
#     x: 760
#     y: 546
#   }
#   vertices {
#     x: 634
#     y: 546
#   }
# }
# , description: "Limited"
# bounding_poly {
#   vertices {
#     x: 773
#     y: 518
#   }
#   vertices {
#     x: 863
#     y: 518
#   }
#   vertices {
#     x: 863
#     y: 541
#   }
#   vertices {
#     x: 773
#     y: 541
#   }
# }
# , description: "Fax:"
# bounding_poly {
#   vertices {
#     x: 942
#     y: 518
#   }
#   vertices {
#     x: 998
#     y: 519
#   }
#   vertices {
#     x: 998
#     y: 541
#   }
#   vertices {
#     x: 942
#     y: 540
#   }
# }
# , description: "1300"
# bounding_poly {
#   vertices {
#     x: 1086
#     y: 520
#   }
#   vertices {
#     x: 1147
#     y: 520
#   }
#   vertices {
#     x: 1147
#     y: 541
#   }
#   vertices {
#     x: 1086
#     y: 541
#   }
# }
# , description: "300"
# bounding_poly {
#   vertices {
#     x: 1159
#     y: 520
#   }
#   vertices {
#     x: 1204
#     y: 520
#   }
#   vertices {
#     x: 1204
#     y: 541
#   }
#   vertices {
#     x: 1159
#     y: 541
#   }
# }
# , description: "021"
# bounding_poly {
#   vertices {
#     x: 1216
#     y: 520
#   }
#   vertices {
#     x: 1257
#     y: 520
#   }
#   vertices {
#     x: 1257
#     y: 541
#   }
#   vertices {
#     x: 1216
#     y: 541
#   }
# }
# , description: "From:"
# bounding_poly {
#   vertices {
#     x: 233
#     y: 585
#   }
#   vertices {
#     x: 310
#     y: 585
#   }
#   vertices {
#     x: 310
#     y: 608
#   }
#   vertices {
#     x: 233
#     y: 608
#   }
# }
# , description: "Victoria"
# bounding_poly {
#   vertices {
#     x: 413
#     y: 585
#   }
#   vertices {
#     x: 508
#     y: 585
#   }
#   vertices {
#     x: 508
#     y: 608
#   }
#   vertices {
#     x: 413
#     y: 608
#   }
# }
# , description: "Weekes"
# bounding_poly {
#   vertices {
#     x: 518
#     y: 585
#   }
#   vertices {
#     x: 622
#     y: 585
#   }
#   vertices {
#     x: 622
#     y: 608
#   }
#   vertices {
#     x: 518
#     y: 608
#   }
# }
# , description: "Fax:"
# bounding_poly {
#   vertices {
#     x: 942
#     y: 585
#   }
#   vertices {
#     x: 998
#     y: 584
#   }
#   vertices {
#     x: 998
#     y: 607
#   }
#   vertices {
#     x: 942
#     y: 608
#   }
# }
# , description: "61"
# bounding_poly {
#   vertices {
#     x: 1085
#     y: 587
#   }
#   vertices {
#     x: 1110
#     y: 587
#   }
#   vertices {
#     x: 1110
#     y: 608
#   }
#   vertices {
#     x: 1085
#     y: 608
#   }
# }
# , description: "2"
# bounding_poly {
#   vertices {
#     x: 1125
#     y: 587
#   }
#   vertices {
#     x: 1139
#     y: 587
#   }
#   vertices {
#     x: 1139
#     y: 608
#   }
#   vertices {
#     x: 1125
#     y: 608
#   }
# }
# , description: "8225"
# bounding_poly {
#   vertices {
#     x: 1151
#     y: 587
#   }
#   vertices {
#     x: 1213
#     y: 587
#   }
#   vertices {
#     x: 1213
#     y: 608
#   }
#   vertices {
#     x: 1151
#     y: 608
#   }
# }
# , description: "5461"
# bounding_poly {
#   vertices {
#     x: 1224
#     y: 587
#   }
#   vertices {
#     x: 1282
#     y: 587
#   }
#   vertices {
#     x: 1282
#     y: 608
#   }
#   vertices {
#     x: 1224
#     y: 608
#   }
# }
# , description: "Company"
# bounding_poly {
#   vertices {
#     x: 414
#     y: 619
#   }
#   vertices {
#     x: 537
#     y: 619
#   }
#   vertices {
#     x: 537
#     y: 648
#   }
#   vertices {
#     x: 414
#     y: 648
#   }
# }
# , description: "Secretary"
# bounding_poly {
#   vertices {
#     x: 547
#     y: 619
#   }
#   vertices {
#     x: 669
#     y: 619
#   }
#   vertices {
#     x: 669
#     y: 648
#   }
#   vertices {
#     x: 547
#     y: 648
#   }
# }
# , description: "Date:"
# bounding_poly {
#   vertices {
#     x: 232
#     y: 689
#   }
#   vertices {
#     x: 299
#     y: 690
#   }
#   vertices {
#     x: 299
#     y: 710
#   }
#   vertices {
#     x: 232
#     y: 709
#   }
# }
# , description: "13"
# bounding_poly {
#   vertices {
#     x: 415
#     y: 689
#   }
#   vertices {
#     x: 443
#     y: 689
#   }
#   vertices {
#     x: 443
#     y: 709
#   }
#   vertices {
#     x: 415
#     y: 709
#   }
# }
# , description: "February"
# bounding_poly {
#   vertices {
#     x: 456
#     y: 688
#   }
#   vertices {
#     x: 569
#     y: 687
#   }
#   vertices {
#     x: 569
#     y: 715
#   }
#   vertices {
#     x: 456
#     y: 716
#   }
# }
# , description: "2003"
# bounding_poly {
#   vertices {
#     x: 579
#     y: 689
#   }
#   vertices {
#     x: 641
#     y: 689
#   }
#   vertices {
#     x: 641
#     y: 709
#   }
#   vertices {
#     x: 579
#     y: 709
#   }
# }
# , description: "Pages:"
# bounding_poly {
#   vertices {
#     x: 942
#     y: 689
#   }
#   vertices {
#     x: 1032
#     y: 689
#   }
#   vertices {
#     x: 1032
#     y: 715
#   }
#   vertices {
#     x: 942
#     y: 715
#   }
# }
# , description: "7"
# bounding_poly {
#   vertices {
#     x: 1084
#     y: 691
#   }
#   vertices {
#     x: 1099
#     y: 691
#   }
#   vertices {
#     x: 1099
#     y: 709
#   }
#   vertices {
#     x: 1084
#     y: 709
#   }
# }
# , description: "(Including"
# bounding_poly {
#   vertices {
#     x: 1110
#     y: 689
#   }
#   vertices {
#     x: 1233
#     y: 689
#   }
#   vertices {
#     x: 1233
#     y: 717
#   }
#   vertices {
#     x: 1110
#     y: 717
#   }
# }
# , description: "cover"
# bounding_poly {
#   vertices {
#     x: 1245
#     y: 695
#   }
#   vertices {
#     x: 1314
#     y: 695
#   }
#   vertices {
#     x: 1314
#     y: 711
#   }
#   vertices {
#     x: 1245
#     y: 711
#   }
# }
# , description: "sheet)"
# bounding_poly {
#   vertices {
#     x: 1325
#     y: 689
#   }
#   vertices {
#     x: 1401
#     y: 689
#   }
#   vertices {
#     x: 1401
#     y: 717
#   }
#   vertices {
#     x: 1325
#     y: 717
#   }
# }
# , description: "Subject:"
# bounding_poly {
#   vertices {
#     x: 231
#     y: 754
#   }
#   vertices {
#     x: 341
#     y: 754
#   }
#   vertices {
#     x: 341
#     y: 783
#   }
#   vertices {
#     x: 231
#     y: 783
#   }
# }
# , description: "Substantial"
# bounding_poly {
#   vertices {
#     x: 413
#     y: 754
#   }
#   vertices {
#     x: 555
#     y: 754
#   }
#   vertices {
#     x: 555
#     y: 777
#   }
#   vertices {
#     x: 413
#     y: 777
#   }
# }
# , description: "Shareholding"
# bounding_poly {
#   vertices {
#     x: 567
#     y: 754
#   }
#   vertices {
#     x: 734
#     y: 754
#   }
#   vertices {
#     x: 734
#     y: 783
#   }
#   vertices {
#     x: 567
#     y: 783
#   }
# }
# , description: "Notice"
# bounding_poly {
#   vertices {
#     x: 747
#     y: 756
#   }
#   vertices {
#     x: 827
#     y: 756
#   }
#   vertices {
#     x: 827
#     y: 777
#   }
#   vertices {
#     x: 747
#     y: 777
#   }
# }
# , description: "If"
# bounding_poly {
#   vertices {
#     x: 130
#     y: 824
#   }
#   vertices {
#     x: 161
#     y: 824
#   }
#   vertices {
#     x: 161
#     y: 849
#   }
#   vertices {
#     x: 130
#     y: 849
#   }
# }
# , description: "you"
# bounding_poly {
#   vertices {
#     x: 164
#     y: 824
#   }
#   vertices {
#     x: 200
#     y: 824
#   }
#   vertices {
#     x: 200
#     y: 849
#   }
#   vertices {
#     x: 164
#     y: 849
#   }
# }
# , description: "do"
# bounding_poly {
#   vertices {
#     x: 203
#     y: 827
#   }
#   vertices {
#     x: 227
#     y: 827
#   }
#   vertices {
#     x: 227
#     y: 846
#   }
#   vertices {
#     x: 203
#     y: 846
#   }
# }
# , description: "not"
# bounding_poly {
#   vertices {
#     x: 237
#     y: 824
#   }
#   vertices {
#     x: 274
#     y: 824
#   }
#   vertices {
#     x: 274
#     y: 849
#   }
#   vertices {
#     x: 237
#     y: 849
#   }
# }
# , description: "receive"
# bounding_poly {
#   vertices {
#     x: 277
#     y: 827
#   }
#   vertices {
#     x: 349
#     y: 827
#   }
#   vertices {
#     x: 349
#     y: 844
#   }
#   vertices {
#     x: 277
#     y: 844
#   }
# }
# , description: "all"
# bounding_poly {
#   vertices {
#     x: 360
#     y: 827
#   }
#   vertices {
#     x: 380
#     y: 827
#   }
#   vertices {
#     x: 380
#     y: 844
#   }
#   vertices {
#     x: 360
#     y: 844
#   }
# }
# , description: "pages,"
# bounding_poly {
#   vertices {
#     x: 390
#     y: 831
#   }
#   vertices {
#     x: 459
#     y: 831
#   }
#   vertices {
#     x: 459
#     y: 849
#   }
#   vertices {
#     x: 390
#     y: 849
#   }
# }
# , description: "please"
# bounding_poly {
#   vertices {
#     x: 469
#     y: 827
#   }
#   vertices {
#     x: 537
#     y: 827
#   }
#   vertices {
#     x: 537
#     y: 849
#   }
#   vertices {
#     x: 469
#     y: 849
#   }
# }
# , description: "telephone"
# bounding_poly {
#   vertices {
#     x: 546
#     y: 827
#   }
#   vertices {
#     x: 648
#     y: 827
#   }
#   vertices {
#     x: 648
#     y: 848
#   }
#   vertices {
#     x: 546
#     y: 848
#   }
# }
# , description: "on"
# bounding_poly {
#   vertices {
#     x: 657
#     y: 831
#   }
#   vertices {
#     x: 680
#     y: 831
#   }
#   vertices {
#     x: 680
#     y: 844
#   }
#   vertices {
#     x: 657
#     y: 844
#   }
# }
# , description: "61"
# bounding_poly {
#   vertices {
#     x: 690
#     y: 827
#   }
#   vertices {
#     x: 710
#     y: 827
#   }
#   vertices {
#     x: 710
#     y: 844
#   }
#   vertices {
#     x: 690
#     y: 844
#   }
# }
# , description: "2"
# bounding_poly {
#   vertices {
#     x: 723
#     y: 827
#   }
#   vertices {
#     x: 734
#     y: 827
#   }
#   vertices {
#     x: 734
#     y: 844
#   }
#   vertices {
#     x: 723
#     y: 844
#   }
# }
# , description: "82254965."
# bounding_poly {
#   vertices {
#     x: 744
#     y: 827
#   }
#   vertices {
#     x: 861
#     y: 827
#   }
#   vertices {
#     x: 861
#     y: 844
#   }
#   vertices {
#     x: 744
#     y: 844
#   }
# }
# , description: "This"
# bounding_poly {
#   vertices {
#     x: 136
#     y: 861
#   }
#   vertices {
#     x: 180
#     y: 861
#   }
#   vertices {
#     x: 180
#     y: 878
#   }
#   vertices {
#     x: 136
#     y: 878
#   }
# }
# , description: "fax"
# bounding_poly {
#   vertices {
#     x: 189
#     y: 861
#   }
#   vertices {
#     x: 219
#     y: 861
#   }
#   vertices {
#     x: 219
#     y: 878
#   }
#   vertices {
#     x: 189
#     y: 878
#   }
# }
# , description: "is"
# bounding_poly {
#   vertices {
#     x: 228
#     y: 861
#   }
#   vertices {
#     x: 242
#     y: 861
#   }
#   vertices {
#     x: 242
#     y: 878
#   }
#   vertices {
#     x: 228
#     y: 878
#   }
# }
# , description: "confidential"
# bounding_poly {
#   vertices {
#     x: 251
#     y: 859
#   }
#   vertices {
#     x: 369
#     y: 859
#   }
#   vertices {
#     x: 369
#     y: 878
#   }
#   vertices {
#     x: 251
#     y: 878
#   }
# }
# , description: "and"
# bounding_poly {
#   vertices {
#     x: 380
#     y: 861
#   }
#   vertices {
#     x: 417
#     y: 861
#   }
#   vertices {
#     x: 417
#     y: 878
#   }
#   vertices {
#     x: 380
#     y: 878
#   }
# }
# , description: "may"
# bounding_poly {
#   vertices {
#     x: 426
#     y: 865
#   }
#   vertices {
#     x: 469
#     y: 865
#   }
#   vertices {
#     x: 469
#     y: 882
#   }
#   vertices {
#     x: 426
#     y: 882
#   }
# }
# , description: "be"
# bounding_poly {
#   vertices {
#     x: 478
#     y: 859
#   }
#   vertices {
#     x: 502
#     y: 859
#   }
#   vertices {
#     x: 502
#     y: 878
#   }
#   vertices {
#     x: 478
#     y: 878
#   }
# }
# , description: "privileged."
# bounding_poly {
#   vertices {
#     x: 511
#     y: 859
#   }
#   vertices {
#     x: 617
#     y: 859
#   }
#   vertices {
#     x: 617
#     y: 882
#   }
#   vertices {
#     x: 511
#     y: 882
#   }
# }
# , description: "If"
# bounding_poly {
#   vertices {
#     x: 635
#     y: 859
#   }
#   vertices {
#     x: 645
#     y: 859
#   }
#   vertices {
#     x: 645
#     y: 878
#   }
#   vertices {
#     x: 635
#     y: 878
#   }
# }
# , description: "you"
# bounding_poly {
#   vertices {
#     x: 652
#     y: 865
#   }
#   vertices {
#     x: 689
#     y: 865
#   }
#   vertices {
#     x: 689
#     y: 882
#   }
#   vertices {
#     x: 652
#     y: 882
#   }
# }
# , description: "are"
# bounding_poly {
#   vertices {
#     x: 698
#     y: 865
#   }
#   vertices {
#     x: 730
#     y: 865
#   }
#   vertices {
#     x: 730
#     y: 878
#   }
#   vertices {
#     x: 698
#     y: 878
#   }
# }
# , description: "not"
# bounding_poly {
#   vertices {
#     x: 740
#     y: 861
#   }
#   vertices {
#     x: 771
#     y: 861
#   }
#   vertices {
#     x: 771
#     y: 878
#   }
#   vertices {
#     x: 740
#     y: 878
#   }
# }
# , description: "the"
# bounding_poly {
#   vertices {
#     x: 778
#     y: 859
#   }
#   vertices {
#     x: 811
#     y: 859
#   }
#   vertices {
#     x: 811
#     y: 878
#   }
#   vertices {
#     x: 778
#     y: 878
#   }
# }
# , description: "intended"
# bounding_poly {
#   vertices {
#     x: 820
#     y: 859
#   }
#   vertices {
#     x: 910
#     y: 859
#   }
#   vertices {
#     x: 910
#     y: 878
#   }
#   vertices {
#     x: 820
#     y: 878
#   }
# }
# , description: "recipient,"
# bounding_poly {
#   vertices {
#     x: 920
#     y: 861
#   }
#   vertices {
#     x: 1014
#     y: 861
#   }
#   vertices {
#     x: 1014
#     y: 882
#   }
#   vertices {
#     x: 920
#     y: 882
#   }
# }
# , description: "please"
# bounding_poly {
#   vertices {
#     x: 1023
#     y: 861
#   }
#   vertices {
#     x: 1091
#     y: 861
#   }
#   vertices {
#     x: 1091
#     y: 882
#   }
#   vertices {
#     x: 1023
#     y: 882
#   }
# }
# , description: "notify"
# bounding_poly {
#   vertices {
#     x: 1101
#     y: 861
#   }
#   vertices {
#     x: 1156
#     y: 861
#   }
#   vertices {
#     x: 1156
#     y: 882
#   }
#   vertices {
#     x: 1101
#     y: 882
#   }
# }
# , description: "the"
# bounding_poly {
#   vertices {
#     x: 1165
#     y: 861
#   }
#   vertices {
#     x: 1196
#     y: 861
#   }
#   vertices {
#     x: 1196
#     y: 878
#   }
#   vertices {
#     x: 1165
#     y: 878
#   }
# }
# , description: "sender"
# bounding_poly {
#   vertices {
#     x: 1205
#     y: 861
#   }
#   vertices {
#     x: 1277
#     y: 861
#   }
#   vertices {
#     x: 1277
#     y: 878
#   }
#   vertices {
#     x: 1205
#     y: 878
#   }
# }
# , description: "immediately"
# bounding_poly {
#   vertices {
#     x: 1286
#     y: 861
#   }
#   vertices {
#     x: 1410
#     y: 861
#   }
#   vertices {
#     x: 1410
#     y: 884
#   }
#   vertices {
#     x: 1286
#     y: 884
#   }
# }
# , description: "by"
# bounding_poly {
#   vertices {
#     x: 1418
#     y: 861
#   }
#   vertices {
#     x: 1441
#     y: 861
#   }
#   vertices {
#     x: 1441
#     y: 884
#   }
#   vertices {
#     x: 1418
#     y: 884
#   }
# }
# , description: "telephone."
# bounding_poly {
#   vertices {
#     x: 1449
#     y: 861
#   }
#   vertices {
#     x: 1558
#     y: 861
#   }
#   vertices {
#     x: 1558
#     y: 884
#   }
#   vertices {
#     x: 1449
#     y: 884
#   }
# }
# , description: "See"
# bounding_poly {
#   vertices {
#     x: 231
#     y: 976
#   }
#   vertices {
#     x: 279
#     y: 976
#   }
#   vertices {
#     x: 279
#     y: 999
#   }
#   vertices {
#     x: 231
#     y: 999
#   }
# }
# , description: "attached."
# bounding_poly {
#   vertices {
#     x: 291
#     y: 976
#   }
#   vertices {
#     x: 407
#     y: 976
#   }
#   vertices {
#     x: 407
#     y: 999
#   }
#   vertices {
#     x: 291
#     y: 999
#   }
# }
# , description: "Document2"
# bounding_poly {
#   vertices {
#     x: 229
#     y: 2048
#   }
#   vertices {
#     x: 335
#     y: 2048
#   }
#   vertices {
#     x: 335
#     y: 2063
#   }
#   vertices {
#     x: 229
#     y: 2063
#   }
# }
# , description: "SALOMON"
# bounding_poly {
#   vertices {
#     x: 235
#     y: 2093
#   }
#   vertices {
#     x: 367
#     y: 2093
#   }
#   vertices {
#     x: 367
#     y: 2123
#   }
#   vertices {
#     x: 235
#     y: 2123
#   }
# }
# , description: "SMITH"
# bounding_poly {
#   vertices {
#     x: 369
#     y: 2097
#   }
#   vertices {
#     x: 448
#     y: 2097
#   }
#   vertices {
#     x: 448
#     y: 2118
#   }
#   vertices {
#     x: 369
#     y: 2118
#   }
# }
# , description: "BARNEY"
# bounding_poly {
#   vertices {
#     x: 461
#     y: 2097
#   }
#   vertices {
#     x: 566
#     y: 2097
#   }
#   vertices {
#     x: 566
#     y: 2118
#   }
#   vertices {
#     x: 461
#     y: 2118
#   }
# }
# , description: "AUSTRALIA"
# bounding_poly {
#   vertices {
#     x: 576
#     y: 2097
#   }
#   vertices {
#     x: 721
#     y: 2097
#   }
#   vertices {
#     x: 721
#     y: 2118
#   }
#   vertices {
#     x: 576
#     y: 2118
#   }
# }
# , description: "PTY"
# bounding_poly {
#   vertices {
#     x: 732
#     y: 2097
#   }
#   vertices {
#     x: 780
#     y: 2097
#   }
#   vertices {
#     x: 780
#     y: 2118
#   }
#   vertices {
#     x: 732
#     y: 2118
#   }
# }
# , description: "LIMITED"
# bounding_poly {
#   vertices {
#     x: 791
#     y: 2097
#   }
#   vertices {
#     x: 893
#     y: 2097
#   }
#   vertices {
#     x: 893
#     y: 2118
#   }
#   vertices {
#     x: 791
#     y: 2118
#   }
# }
# , description: "ABN"
# bounding_poly {
#   vertices {
#     x: 227
#     y: 2126
#   }
#   vertices {
#     x: 282
#     y: 2126
#   }
#   vertices {
#     x: 282
#     y: 2150
#   }
#   vertices {
#     x: 227
#     y: 2150
#   }
# }
# , description: "56"
# bounding_poly {
#   vertices {
#     x: 284
#     y: 2126
#   }
#   vertices {
#     x: 315
#     y: 2126
#   }
#   vertices {
#     x: 315
#     y: 2150
#   }
#   vertices {
#     x: 284
#     y: 2150
#   }
# }
# , description: "081"
# bounding_poly {
#   vertices {
#     x: 318
#     y: 2129
#   }
#   vertices {
#     x: 352
#     y: 2129
#   }
#   vertices {
#     x: 352
#     y: 2148
#   }
#   vertices {
#     x: 318
#     y: 2148
#   }
# }
# , description: "472684"
# bounding_poly {
#   vertices {
#     x: 365
#     y: 2129
#   }
#   vertices {
#     x: 450
#     y: 2129
#   }
#   vertices {
#     x: 450
#     y: 2148
#   }
#   vertices {
#     x: 365
#     y: 2148
#   }
# }
# , description: "Level"
# bounding_poly {
#   vertices {
#     x: 229
#     y: 2159
#   }
#   vertices {
#     x: 283
#     y: 2159
#   }
#   vertices {
#     x: 283
#     y: 2176
#   }
#   vertices {
#     x: 229
#     y: 2176
#   }
# }
# , description: "40,"
# bounding_poly {
#   vertices {
#     x: 293
#     y: 2159
#   }
#   vertices {
#     x: 322
#     y: 2159
#   }
#   vertices {
#     x: 322
#     y: 2180
#   }
#   vertices {
#     x: 293
#     y: 2180
#   }
# }
# , description: "Citigroup"
# bounding_poly {
#   vertices {
#     x: 333
#     y: 2157
#   }
#   vertices {
#     x: 426
#     y: 2157
#   }
#   vertices {
#     x: 426
#     y: 2180
#   }
#   vertices {
#     x: 333
#     y: 2180
#   }
# }
# , description: "Centre,"
# bounding_poly {
#   vertices {
#     x: 437
#     y: 2157
#   }
#   vertices {
#     x: 511
#     y: 2157
#   }
#   vertices {
#     x: 511
#     y: 2178
#   }
#   vertices {
#     x: 437
#     y: 2178
#   }
# }
# , description: "2"
# bounding_poly {
#   vertices {
#     x: 522
#     y: 2157
#   }
#   vertices {
#     x: 532
#     y: 2157
#   }
#   vertices {
#     x: 532
#     y: 2176
#   }
#   vertices {
#     x: 522
#     y: 2176
#   }
# }
# , description: "Park"
# bounding_poly {
#   vertices {
#     x: 543
#     y: 2157
#   }
#   vertices {
#     x: 588
#     y: 2157
#   }
#   vertices {
#     x: 588
#     y: 2176
#   }
#   vertices {
#     x: 543
#     y: 2176
#   }
# }
# , description: "Street,"
# bounding_poly {
#   vertices {
#     x: 599
#     y: 2154
#   }
#   vertices {
#     x: 671
#     y: 2154
#   }
#   vertices {
#     x: 671
#     y: 2181
#   }
#   vertices {
#     x: 599
#     y: 2181
#   }
# }
# , description: "Sydney"
# bounding_poly {
#   vertices {
#     x: 674
#     y: 2157
#   }
#   vertices {
#     x: 751
#     y: 2157
#   }
#   vertices {
#     x: 751
#     y: 2180
#   }
#   vertices {
#     x: 674
#     y: 2180
#   }
# }
# , description: "NSW"
# bounding_poly {
#   vertices {
#     x: 761
#     y: 2157
#   }
#   vertices {
#     x: 813
#     y: 2157
#   }
#   vertices {
#     x: 813
#     y: 2176
#   }
#   vertices {
#     x: 761
#     y: 2176
#   }
# }
# , description: "2000"
# bounding_poly {
#   vertices {
#     x: 822
#     y: 2156
#   }
#   vertices {
#     x: 874
#     y: 2156
#   }
#   vertices {
#     x: 874
#     y: 2176
#   }
#   vertices {
#     x: 822
#     y: 2176
#   }
# }
# , description: "GPO"
# bounding_poly {
#   vertices {
#     x: 229
#     y: 2187
#   }
#   vertices {
#     x: 279
#     y: 2187
#   }
#   vertices {
#     x: 279
#     y: 2204
#   }
#   vertices {
#     x: 229
#     y: 2204
#   }
# }
# , description: "Box"
# bounding_poly {
#   vertices {
#     x: 292
#     y: 2183
#   }
#   vertices {
#     x: 333
#     y: 2183
#   }
#   vertices {
#     x: 333
#     y: 2208
#   }
#   vertices {
#     x: 292
#     y: 2208
#   }
# }
# , description: "557,"
# bounding_poly {
#   vertices {
#     x: 337
#     y: 2187
#   }
#   vertices {
#     x: 380
#     y: 2187
#   }
#   vertices {
#     x: 380
#     y: 2208
#   }
#   vertices {
#     x: 337
#     y: 2208
#   }
# }
# , description: "Sydney"
# bounding_poly {
#   vertices {
#     x: 391
#     y: 2185
#   }
#   vertices {
#     x: 469
#     y: 2185
#   }
#   vertices {
#     x: 469
#     y: 2208
#   }
#   vertices {
#     x: 391
#     y: 2208
#   }
# }
# , description: "NSW"
# bounding_poly {
#   vertices {
#     x: 479
#     y: 2185
#   }
#   vertices {
#     x: 531
#     y: 2185
#   }
#   vertices {
#     x: 531
#     y: 2204
#   }
#   vertices {
#     x: 479
#     y: 2204
#   }
# }
# , description: "2001"
# bounding_poly {
#   vertices {
#     x: 541
#     y: 2187
#   }
#   vertices {
#     x: 587
#     y: 2187
#   }
#   vertices {
#     x: 587
#     y: 2204
#   }
#   vertices {
#     x: 541
#     y: 2204
#   }
# }
# , description: "Australia"
# bounding_poly {
#   vertices {
#     x: 600
#     y: 2185
#   }
#   vertices {
#     x: 689
#     y: 2185
#   }
#   vertices {
#     x: 689
#     y: 2204
#   }
#   vertices {
#     x: 600
#     y: 2204
#   }
# }
# , description: "TELEPHONE:"
# bounding_poly {
#   vertices {
#     x: 1069
#     y: 2156
#   }
#   vertices {
#     x: 1219
#     y: 2157
#   }
#   vertices {
#     x: 1219
#     y: 2177
#   }
#   vertices {
#     x: 1069
#     y: 2176
#   }
# }
# , description: "61282254000"
# bounding_poly {
#   vertices {
#     x: 1235
#     y: 2157
#   }
#   vertices {
#     x: 1400
#     y: 2158
#   }
#   vertices {
#     x: 1400
#     y: 2177
#   }
#   vertices {
#     x: 1235
#     y: 2176
#   }
# }
# , description: "FACSIMILE:"
# bounding_poly {
#   vertices {
#     x: 1070
#     y: 2185
#   }
#   vertices {
#     x: 1200
#     y: 2185
#   }
#   vertices {
#     x: 1200
#     y: 2204
#   }
#   vertices {
#     x: 1070
#     y: 2204
#   }
# }
# , description: "61"
# bounding_poly {
#   vertices {
#     x: 1237
#     y: 2187
#   }
#   vertices {
#     x: 1258
#     y: 2187
#   }
#   vertices {
#     x: 1258
#     y: 2204
#   }
#   vertices {
#     x: 1237
#     y: 2204
#   }
# }
# , description: "2"
# bounding_poly {
#   vertices {
#     x: 1270
#     y: 2187
#   }
#   vertices {
#     x: 1281
#     y: 2187
#   }
#   vertices {
#     x: 1281
#     y: 2204
#   }
#   vertices {
#     x: 1270
#     y: 2204
#   }
# }
# , description: "8225"
# bounding_poly {
#   vertices {
#     x: 1290
#     y: 2187
#   }
#   vertices {
#     x: 1342
#     y: 2187
#   }
#   vertices {
#     x: 1342
#     y: 2204
#   }
#   vertices {
#     x: 1290
#     y: 2204
#   }
# }
# , description: "5461"
# bounding_poly {
#   vertices {
#     x: 1350
#     y: 2187
#   }
#   vertices {
#     x: 1397
#     y: 2187
#   }
#   vertices {
#     x: 1397
#     y: 2204
#   }
#   vertices {
#     x: 1350
#     y: 2204
#   }
# }
# ]

# %%
import proto
serializable_tags = [proto.Message.to_dict(tag) for tag in texts]
print(serializable_tags)
# Out:
# [{'locale': 'en', 'description': '13. Feb. 2013 10:50\nSSB AUSTRALIA 612 92512997\nNc. 5167 P. 1/7\nSALOMON SMITHBARNEY\nAmemberof citigroup.\nfacsimile\nTo:\nThe IndexShares Fund\nFax:\n61 2 8295 8659\nTo:\nAustralian Stock Exchange Limited\nFax:\n1300 300 021\nFrom:\nVictoria Weekes\nFax:\n61 2 8225 5461\nCompany Secretary\nDate:\n13 February 2003\nPages:\n7 (Including cover sheet)\nSubject:\nSubstantial Shareholding Notice\nIf you do not receive all pages, please telephone on 61 2 82254965.\nThis fax is confidential and may be privileged. If you are not the intended recipient, please notify the sender immediately by telephone.\nSee attached.\nDocument2\nSALOMON SMITH BARNEY AUSTRALIA PTY LIMITED\nABN 56 081 472684\nLevel 40, Citigroup Centre, 2 Park Street, Sydney NSW 2000\nGPO Box 557, Sydney NSW 2001 Australia\nTELEPHONE: 61282254000\nFACSIMILE:\n61 2 8225 5461\n', 'bounding_poly': {'vertices': [{'x': 130, 'y': 0}, {'x': 1558, 'y': 0}, {'x': 1558, 'y': 2208}, {'x': 130, 'y': 2208}], 'normalized_vertices': []}, 'mid': '', 'score': 0.0, 'confidence': 0.0, 'topicality': 0.0, 'locations': [], 'properties': []}, {'description': '13.', 'bounding_poly': {'vertices': [{'x': 142, 'y': 8}, {'x': 169, 'y': 8}, {'x': 169, 'y': 35}, {'x': 142, 'y': 35}], 'normalized_vertices': []}, 'mid': '', 'locale': '', 'score': 0.0, 'confidence': 0.0, 'topicality': 0.0, 'locations': [], 'properties': []}, {'description': 'Feb.', 'bounding_poly': {'vertices': [{'x': 184, 'y': 8}, {'x': 231, 'y': 8}, {'x': 231, 'y': 35}, {'x': 184, 'y': 35}], 'normalized_vertices': []}, 'mid': '', 'locale': '', 'score': 0.0, 'confidence': 0.0, 'topicality': 0.0, 'locations': [], 'properties': []}, {'description': '2013', 'bounding_poly': {'vertices': [{'x': 246, 'y': 8}, {'x': 301, 'y': 8}, {'x': 301, 'y': 35}, {'x': 246, 'y': 35}], 'normalized_vertices': []}, 'mid': '', 'locale': '', 'score': 0.0, 'confidence': 0.0, 'topicality': 0.0, 'locations': [], 'properties': []}, {'description': '10:50', 'bounding_poly': {'vertices': [{'x': 340, 'y': 8}, {'x': 407, 'y': 8}, {'x': 407, 'y': 35}, {'x': 340, 'y': 35}], 'normalized_vertices': []}, 'mid': '', 'locale': '', 'score': 0.0, 'confidence': 0.0, 'topicality': 0.0, 'locations': [], 'properties': []}, {'description': 'SSB', 'bounding_poly': {'vertices': [{'x': 506, 'y': 8}, {'x': 545, 'y': 8}, {'x': 545, 'y': 33}, {'x': 506, 'y': 33}], 'normalized_vertices': []}, 'mid': '', 'locale': '', 'score': 0.0, 'confidence': 0.0, 'topicality': 0.0, 'locations': [], 'properties': []}, {'description': 'AUSTRALIA', 'bounding_poly': {'vertices': [{'x': 566, 'y': 8}, {'x': 699, 'y': 8}, {'x': 699, 'y': 33}, {'x': 566, 'y': 33}], 'normalized_vertices': []}, 'mid': '', 'locale': '', 'score': 0.0, 'confidence': 0.0, 'topicality': 0.0, 'locations': [], 'properties': []}, {'description': '612', 'bounding_poly': {'vertices': [{'x': 720, 'y': 8}, {'x': 758, 'y': 8}, {'x': 758, 'y': 35}, {'x': 720, 'y': 35}], 'normalized_vertices': []}, 'mid': '', 'locale': '', 'score': 0.0, 'confidence': 0.0, 'topicality': 0.0, 'locations': [], 'properties': []}, {'description': '92512997', 'bounding_poly': {'vertices': [{'x': 781, 'y': 8}, {'x': 895, 'y': 8}, {'x': 895, 'y': 35}, {'x': 781, 'y': 35}], 'normalized_vertices': []}, 'mid': '', 'locale': '', 'score': 0.0, 'confidence': 0.0, 'topicality': 0.0, 'locations': [], 'properties': []}, {'description': 'Nc.', 'bounding_poly': {'vertices': [{'x': 1216, 'y': 0}, {'x': 1267, 'y': 0}, {'x': 1267, 'y': 39}, {'x': 1216, 'y': 39}], 'normalized_vertices': []}, 'mid': '', 'locale': '', 'score': 0.0, 'confidence': 0.0, 'topicality': 0.0, 'locations': [], 'properties': []}, {'description': '5167', 'bounding_poly': {'vertices': [{'x': 1268, 'y': 8}, {'x': 1323, 'y': 8}, {'x': 1323, 'y': 35}, {'x': 1268, 'y': 35}], 'normalized_vertices': []}, 'mid': '', 'locale': '', 'score': 0.0, 'confidence': 0.0, 'topicality': 0.0, 'locations': [], 'properties': []}, {'description': 'P.', 'bounding_poly': {'vertices': [{'x': 1374, ' ...

# %%
import json
with open('/content/scanned_document.json','w') as f:
  json.dump(serializable_tags,f)
